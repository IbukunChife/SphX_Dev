# %%
import os
from collections import Counter

def construir_dicionario():




diretorio = "noticias/"
files = os.listdir(diretorio)

notice = [diretorio +  note for note in files]


palavras = []
contador_noticia = len (notice)
for note in notice:
    f = open(note)
    blob = f.read()
    palavras += blob.split(" ")
    print (contador_noticia)
    contador_noticia -= 1
print (palavras)


for i in range(len(palavras)):
    if not palavras[i].isalpha():
        palavras[i]="" 

dictionary = Counter(palavras)
print (dictionary.most_common(3000))
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# ['Com', 'o', 'objetivo', 'de', 'debater', 'os', 'principais', 'desafios', 'das', 'pessoas', 'diagnosticadas', 'com', 'câncer', 'de', 'pulmão,', 'o', 'Instituto', 'Oncoguia', 'promove', 'nesta', 'terça-feira,', '27,', 'um', 'fórum', 'temático', 'para', 'avaliar', 'o', 'cenário', 'da', 'doença', 'no', 'país.\n\nO', 'II', 'Fórum', 'Temático', '-', 'Câncer', 'de', 'Pulmão', 'acontece', 'hoje', 'em', 'São', 'Paulo', 'e', 'contará', 'com', 'a', 'participação', 'de', 'especialistas', 'na', 'área', 'pacientes,', 'gestores', 'de', 'saúde,', 'além', 'de', 'profissionais', 'da', 'imprensa.\n\nSegundo', 'o', 'Instituto', 'Oncoguia,', 'durante', 'o', 'fórum', 'será', 'abordado', 'temas', 'como', 'prevenção,', 'o', 'cenário', 'do', 'câncer', 'de', 'pulmão', 'na', 'América', 'Latina,', 'combate', 'ao', 'tabagismo,', 'diagnóstico', 'precoce,', 'prioridades', 'dos', 'gestores', 'da', 'saúde', 'no', 'combate', 'à', 'doença,', 'além', 'das', 'novidades', 'e', 'entraves', 'no', 'tratamento.\n\nINSTITUTO', 'ONCOGUIA', '-', 'A', 'ONG', 'Instituto', 'Oncoguia', 'foi', 'fundada', 'em', '2009', 'por', 'um', 'grupo', 'de', 'profissionais', 'de', 'saúde', 'e', 'ex-pacientes', 'de', 'câncer.', 'Dessa', 'união', 'nasceu', 'uma', 'associação', 'sem', 'fins', 'lucrativos,', 'criada', 'e', 'idealizada', 'com', 'o', 'objetivo', 'de', 'ajudar', 'o', 'paciente', 'com', 'câncer', 'a', 'viver', 'melhor', 'por', 'meio', 'de', 'projetos', 'e', 'ações', 'de', 'informação', 'de', 'qualidade,', 'educação', 'em', 'saúde,', 'apoio', 'e', 'orientação', 'ao', 'paciente,', 'defesa', 'de', 'direitos', 'e', 'advocacia.\n\n\nConfira', 'a', 'programação', 'completa', 'abaixo:\n\n\n11h00', '-', '11h30', '|', 'Credenciamento\n\n11h30', '-', '11h45', '|', 'Abertura', 'institucional\n\n-', 'Luciana', 'Holtz,', 'fundadora', 'e', 'presidente', '-', 'Instituto', 'Oncoguia\n\n11h45', '-', '12h10', '', '|', 'Cenário', 'do', 'câncer', 'de', 'pulmão', 'na', 'América', 'Latina', '-', 'Apresentação', 'do', 'Relatório', 'The', 'Economist\n\n-', 'Márcio', 'Zanetti,', 'diretor', '-', '', 'Economist', 'Intelligence', 'Unit', '(EIU)', 'para', 'o', 'Brasil.\n\n12h10', '-', '12h30', '', '|', 'Combate', 'ao', 'tabagismo', 'no', 'Brasil:', 'Desafios', 'e', 'avanços\n\n-', 'Mônica', 'Andreis,', 'diretora', 'executiva', '-', 'Aliança', 'de', 'Controle', 'do', 'Tabagismo', '(ACT', 'Promoção', 'da', 'saúde)\n\n12h30', '-', '13h30', '|', 'Almoço\n\n13h30', '', '-', '14h00', '', '|', 'Cenário', 'do', 'Câncer', 'de', 'Pulmão', 'no', 'Brasil\n\n-', 'Clarissa', 'Mathias,', 'médica', 'oncologista', 'e', 'diretora', 'da', 'América', 'Latina', 'na', 'Association', 'for', 'Study', 'on', 'Lung', 'Cancer', '(IASL)\n\n14h30', '', '-', '15h45', '', '|', 'Diagnóstico', 'Precoce', 'do', 'Câncer', 'de', 'pulmão', '-', 'A', 'realidade', 'no', 'Brasil\n\nEspecialistas', 'convidados:\n\n-', 'Ricardo', 'Santos,', 'Professor', 'da', 'Pós', 'Graduação', 'Multidisciplinar', 'e', 'pesquisador', 'no', 'Instituto', 'Israelita', 'de', 'Ensino', 'e', 'Pesquisa', '-', 'IIEP\n\n-', 'Mauro', 'Musa', 'Zamboni,', 'comitê', 'científico', '-', 'Sociedade', 'Brasileira', 'de', 'Pneumologia', 'e', 'Tisiologia', '(SBPT)\n\n-', 'Christina', 'Shiang,', 'Médica', 'Patologista', 'do', 'Laboratório', 'de', 'Anatomia', 'Patológica', 'do', 'Hospital', 'Albert', 'Einstein\n\n-', 'Alfredo', 'Scaff,', 'Consultor', 'médico', 'da', 'Fundação', 'Ary', 'Frauzino', 'para', 'Pesquisa', 'e', 'Controle', 'do', 'Câncer', '(Fundação', 'do', 'Câncer)\n\n15h45', '-', '16h15', '', '|', 'Coffee', 'Break\n\n16h15', '-', '17h15', '', '', '|', 'Novidades', 'e', 'desafios', 'no', 'tratamento', 'de', 'câncer', 'de', 'pulmão', 'Assuntos', 'que', 'serão', 'abordados:\n\n-', 'Clarissa', 'Baldoto,', 'Diretora', 'de', 'Integração', 'Oncológica', 'Oncologia', "D'Or", 'e', 'Membro', 'da', 'Diretoria', 'GBOT', 'e', 'SBOC\n\n-', 'Marcelo', 'Cruz,', 'Médico', 'Oncologista', '–', 'Programa', 'de', 'Desenvolvimento', 'Terapêutico', 'de', 'Hematologia/Oncologia\n\n-', 'Renata', 'E ...
# [('', 640), ('de', 178), ('e', 111), ('o', 65), ('a', 61), ('que', 56), ('do', 53), ('da', 49), ('para', 42), ('em', 39), ('com', 36), ('no', 30), ('às', 23), ('na', 21), ('os', 19), ('um', 18), ('dos', 18), ('é', 18), ('uma', 15), ('ano', 13), ('foi', 11), ('A', 10), ('por', 10), ('dia', 10), ('muito', 10), ('ser', 9), ('se', 9), ('ao', 8), ('sua', 8), ('as', 8), ('não', 8), ('até', 8), ('mais', 8), ('gente', 8), ('como', 7), ('pelo', 7), ('está', 7), ('ainda', 7), ('tem', 7), ('objetivo', 6), ('das', 6), ('câncer', 6), ('melhor', 6), ('O', 6), ('pela', 6), ('também', 6), ('ganhar', 6), ('vem', 6), ('categoria', 6), ('Instituto', 5), ('São', 5), ('área', 5), ('já', 5), ('trabalho', 5), ('público', 5), ('Exposição', 5), ('Espaço', 5), ('Azul', 5), ('campeão', 5), ('nosso', 5), ('Câncer', 4), ('além', 4), ('será', 4), ('pulmão', 4), ('à', 4), ('Hospital', 4), ('Boa', 4), ('aos', 4), ('esse', 4), ('série', 4), ('somente', 4), ('escola', 4), ('duas', 4), ('gostaria', 4), ('são', 4), ('outros', 4), ('Mostra', 4), ('Concurso', 4), ('Mania', 4), ('trabalhar', 4), ('desafios', 3), ('nesta', 3), ('hoje', 3), ('gestores', 3), ('América', 3), ('combate', 3), ('meio', 3), ('programação', 3), ('presidente', 3), ('Desafios', 3), ('Pesquisa', 3), ('serão', 3), ('experiência', 3), ('José', 3), ('Ministério', 3), ('novas', 3), ('pagamento', 3), ('servidores', 3), ('salários', 3), ('novembro', 3), ('Mas', 3), ('meu', 3), ('desta', 3), ('Papai', 3), ('ela', 3), ('seu', 3), ('poder', 3), ('ou', 3), ('Um', 3), ('kit', 3), ('eu', 3), ('minha', 3), ('Eu', 3), ('somos', 3), ('mostra', 3), ('ter', 3), ('porque', 3), ('mandados', 3), ('contra', 3), ('maior', 3), ('onde', 3), ('foram', 3), ('Estadual', 3), ('Roraima', 3), ('feira', 3), ('concursos', 3), ('UERR', 3), ('inscrições', 3), ('podem', 3), ('batalha', 3), ('Swordplay', 3), ('Campeonato', 3), ('Aldenor', 3), ('mas', 3), ('Cultural', 3), ('Pimentel', 3), ('fica', 3), ('título', 3), ('competição', 3), ('veio', 3), ('Com', 2), ('Oncoguia', 2), ('fórum', 2), ('cenário', 2), ('Pulmão', 2), ('acontece', 2), ('profissionais', 2), ('durante', 2), ('temas', 2), ('prioridades', 2), ('saúde', 2), ('grupo', 2), ('criada', 2), ('ações', 2), ('apoio', 2), ('Cenário', 2), ('Latina', 2), ('Apresentação', 2), ('Combate', 2), ('diretora', 2), ('Controle', 2), ('Clarissa', 2), ('for', 2), ('pesquisador', 2), ('Oncologia', 2), ('Médico', 2), ('Oncologista', 2), ('gestor', 2), ('Rio', 2), ('Nacional', 2), ('Centro', 2), ('vereador', 2), ('Fernandes', 2), ('esclareceu', 2), ('data', 2), ('revelou', 2), ('manhã', 2), ('bancos', 2), ('primeiro', 2), ('todos', 2), ('algo', 2), ('forma', 2), ('sempre', 2), ('aqui', 2), ('pedir', 2), ('pode', 2), ('quinto', 2), ('pagar', 2), ('conta', 2), ('intenção', 2), ('vereadores', 2), ('maioria', 2), ('começa', 2), ('Em', 2), ('quatro', 2), ('Noel', 2), ('crianças', 2), ('coisas', 2), ('Os', 2), ('cordões', 2), ('maquiagem', 2), ('cor', 2), ('estudante', 2), ('dezembro', 2), ('tudo', 2), ('bem', 2), ('essa', 2), ('carta', 2), ('desejo', 2), ('muitas', 2), ('você', 2), ('presentes', 2), ('menos', 2), ('Uma', 2), ('mãe', 2), ('todas', 2), ('dois', 2), ('suas', 2), ('muita', 2), ('quero', 2), ('escrito', 2), ('outro', 2), ('amo', 2), ('grande', 2), ('tenho', 2), ('poderão', 2), ('Polícia', 2), ('operação', 2), ('organização', 2), ('dentro', 2), ('presídio', 2), ('prisão', 2), ('preventiva', 2), ('atentados', 2), ('após', 2), ('PF', 2), ('nas', 2), ('trabalhos', 2), ('Divisão', 2), ('Inteligência', 2), ('Captura', 2), ('Secretaria', 2), ('Justiça', 2), ('Cidadania', 2), ('ocorre', 2), ('sendo', 2), ('lançamento', 2), ('Geek', 2), ('atrações', 2), ('primeira', 2), ('Universidade', 2), ('bairro', 2), ('festival', 2), ('explica', 2), ('jovem', 2), ('Na', 2), ('campeonatos', 2), ('Cine', 2), ('produtos', 2), ('produção', 2), ('desenvolvimento', 2), ('trazer', 2), ('voltado', 2), ('perspectiva', 2), ('digital', 2), ('atividades', 2), ('feitas', 2), ('nome', 2), ('regras', 2), ('parte', 2),  ...
